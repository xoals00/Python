# %%
import requests

# %%
riot_api_key = 'RGAPI-f94a4128-cb3b-4303-b92b-0016fa59b5a8'

# %%
url = f'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={riot_api_key}'

# %%
res = requests.get(url).json()

# %%
res
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': '966df365-7dea-34ca-839a-2cec050ba64a',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Nami's Alliance",
#  'entries': [{'summonerId': '9KuCeXlLmK2QsE8VULTuAraLvjfdEJXvEm7XsbvC3wsYlhJUNzP2MwRCuw',
#    'summonerName': 'Arnold Hur',
#    'leaguePoints': 1296,
#    'rank': 'I',
#    'wins': 371,
#    'losses': 295,
#    'veteran': True,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
#   {'summonerId': 'CQRr9Xf0TMeI-vs5qwoHqVrUFPd75nj9DaOaEcYjdtTv9pA',
#    'summonerName': '모래상자',
#    'leaguePoints': 1010,
#    'rank': 'I',
#    'wins': 405,
#    'losses': 363,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': False},
#   {'summonerId': 'j3lRetBa4srOm1QRFmy0oX6Kd8OEqvhR-lNYFbVvs4A_26drl1a9s-jCwg',
#    'summonerName': 'BRO Pollu',
#    'leaguePoints': 941,
#    'rank': 'I',
#    'wins': 575,
#    'losses': 534,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
# ...

# %%
res.keys()
# Out:
# dict_keys(['tier', 'leagueId', 'queue', 'name', 'entries'])

# %%
res['tier']
# Out:
# 'CHALLENGER'

# %%
res['leagueId']
# Out:
# '966df365-7dea-34ca-839a-2cec050ba64a'

# %%
res['queue']
# Out:
# 'RANKED_SOLO_5x5'

# %%
res['name']
# Out:
# "Nami's Alliance"

# %%
res['entries'][0]
# Out:
# {'summonerId': '9KuCeXlLmK2QsE8VULTuAraLvjfdEJXvEm7XsbvC3wsYlhJUNzP2MwRCuw',
#  'summonerName': 'Arnold Hur',
#  'leaguePoints': 1296,
#  'rank': 'I',
#  'wins': 371,
#  'losses': 295,
#  'veteran': True,
#  'inactive': False,
#  'freshBlood': False,
#  'hotStreak': False}

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/9KuCeXlLmK2QsE8VULTuAraLvjfdEJXvEm7XsbvC3wsYlhJUNzP2MwRCuw?api_key={riot_api_key}'

# %%
res2 = requests.get(url2).json()

# %%
res2
# Out:
# {'id': '9KuCeXlLmK2QsE8VULTuAraLvjfdEJXvEm7XsbvC3wsYlhJUNzP2MwRCuw',
#  'accountId': 'bo0mRkHD2lzVmBkCNAJzV_cyCs9iZ2sNYfrgZtgTKvl8Na9O4MkLZLbg',
#  'puuid': '-Bb_EWpI6aQ8bB9-Ekv16N2Zw7RFjge0qEymKyXIiCVatekRXWicEZvEZ-Grn66iYevVTlkspH9U6g',
#  'name': 'Arnold Hur',
#  'profileIconId': 22,
#  'revisionDate': 1701714935000,
#  'summonerLevel': 83}

# %%
url3 = f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-puuid/bo0mRkHD2lzVmBkCNAJzV_cyCs9iZ2sNYfrgZtgTKvl8Na9O4MkLZLbg?api_key={riot_api_key}'

# %%
res3 = requests.get(url3).json()

# %%
res3
# Out:
# {'status': {'message': 'Bad Request - Expected message of type puuid, but found accountId',
#   'status_code': 400}}

# %%
url4= f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/%EA%B9%A1%ED%86%B5%EC%B0%A8%EA%B8%B0%EA%B5%AD%EB%82%B41%EC%9C%84/kr1?api_key={riot_api_key}'

# %%
res4 = requests.get(url4).json()

# %%
res4
# Out:
# {'puuid': 'ILvForIkTc9AHZ7g2dAwzOp5MqiSP0o11m_I-4xRgvM640rprYRJuzSlWR3tMa99MqBf8UvO4pIlPA',
#  'gameName': '깡통차기국내1위',
#  'tagLine': 'KR1'}

# %%
url5= 'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/ILvForIkTc9AHZ7g2dAwzOp5MqiSP0o11m_I-4xRgvM640rprYRJuzSlWR3tMa99MqBf8UvO4pIlPA/ids?start=0&count=20&api_key=RGAPI-f94a4128-cb3b-4303-b92b-0016fa59b5a8'

# %%
res5 = requests.get(url5).json()

# %%
res5
# Out:
# ['KR_6855659717',
#  'KR_6855159504',
#  'KR_6855121551',
#  'KR_6855080496',
#  'KR_6855037920',
#  'KR_6854976566',
#  'KR_6854789202',
#  'KR_6854312974',
#  'KR_6854288417',
#  'KR_6854254644',
#  'KR_6850174116',
#  'KR_6850133361',
#  'KR_6850104471',
#  'KR_6850072677',
#  'KR_6850039867',
#  'KR_6850014509',
#  'KR_6849984712',
#  'KR_6849961353',
#  'KR_6849924786',
#  'KR_6849903559']

# %%
url6 = 'https://asia.api.riotgames.com/lol/match/v5/matches/KR_6855659717?api_key=RGAPI-f94a4128-cb3b-4303-b92b-0016fa59b5a8'

# %%
res6 = requests.get(url6).json()

# %%
res6.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
res6['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_6855659717',
#  'participants': ['xGIwwSPcoxVePrE2rm8lvKz0JWb1jaG5Ucz1U_KBaqcSywP4_Vk623omax8l8OE9J5_vPsQNqB7T_w',
#   'HZeupHnwhW3uHvd_q5xAeyBEzuH2xJ1uOzcmQ7UL6klsr_9RHRSOZcTuEsjNWD7hiuWMlLsM6SoCOw',
#   '8SqJYXnEYXUFwYd_tjJh-3VCARDzzzsONmbdzy_S3lUmS2Ue2fM215NGopadvIQQHyxpUlk9JX94Ww',
#   'ILvForIkTc9AHZ7g2dAwzOp5MqiSP0o11m_I-4xRgvM640rprYRJuzSlWR3tMa99MqBf8UvO4pIlPA',
#   '8N47foCQ8GdMj-5JxUnV2RO9EqSOKnk9ybhcjAMJ0i8cChXjlDdgGOFJST_O5a3lIJvlJ0jznfir1A',
#   'Ll7GsyGE3IW2P4PJpq24LBFzsDtnevfwlfkd-IHrsXOjW1avWYTHieFEZTDQXDmMB4qwSQ0UJELIKQ',
#   'wxS2WRA7dsUbeHei1vu5nNSVJDirzqrcxSjjiijkX9ML8c7OZtaZ5lS1PQRi0axbbYUULNMBf0dAOw',
#   'GvGy7uhoEcu0fWG60x-7gVrOF3wmsj2wndDQgUM4xuyi1WxbV6j5gfdKbUrI6dWeSkcwUGJwnUUE2Q',
#   '7-fXy8RDHRTcAhUPHDQTaLBljw3ZcaXZU2-l7_7n1a-W0TSdjoyX7TEFv8tlelY7BKPtpFp1dUd-ww',
#   '8jQErmNdePuEZPbr0eSZ3wuZ4rrs0442CyIkl6OtJzAAuT7_mdv-5WcFG8NWwgv-UOanv8ntBvhsdg']}

# %%
res6['info']
# Out:
# {'gameCreation': 1702821588630,
#  'gameDuration': 950,
#  'gameEndTimestamp': 1702822580501,
#  'gameId': 6855659717,
#  'gameMode': 'ARAM',
#  'gameName': 'teambuilder-match-6855659717',
#  'gameStartTimestamp': 1702821629941,
#  'gameType': 'MATCHED_GAME',
#  'gameVersion': '13.24.547.9214',
#  'mapId': 12,
#  'participants': [{'allInPings': 0,
#    'assistMePings': 0,
#    'assists': 24,
#    'baitPings': 0,
#    'baronKills': 0,
#    'basicPings': 0,
#    'bountyLevel': 1,
#    'challenges': {'12AssistStreakCount': 1,
#     'abilityUses': 162,
#     'acesBefore15Minutes': 2,
#     'alliedJungleMonsterKills': 0,
#     'baronTakedowns': 0,
#     'blastConeOppositeOpponentCount': 0,
#     'bountyGold': 300,
#     'buffsStolen': 0,
#     'completeSupportQuestInTime': 0,
#     'controlWardsPlaced': 0,
#     'damagePerMinute': 1017.3598969869885,
#     'damageTakenOnTeamPercentage': 0.12416529279422708,
#     'dancedWithRiftHerald': 0,
#     'deathsByEnemyChamps': 4,
# ...

# %%
res6['info'].keys()
# Out:
# dict_keys(['gameCreation', 'gameDuration', 'gameEndTimestamp', 'gameId', 'gameMode', 'gameName', 'gameStartTimestamp', 'gameType', 'gameVersion', 'mapId', 'participants', 'platformId', 'queueId', 'teams', 'tournamentCode'])

# %%
res6['info']['platformId']
# Out:
# 'KR'

# %%
res6['info']['queueId']
# Out:
# 450

# %%
res6['info']['teams']
# Out:
# [{'bans': [],
#   'objectives': {'baron': {'first': False, 'kills': 0},
#    'champion': {'first': True, 'kills': 50},
#    'dragon': {'first': False, 'kills': 0},
#    'horde': {'first': False, 'kills': 0},
#    'inhibitor': {'first': True, 'kills': 1},
#    'riftHerald': {'first': False, 'kills': 0},
#    'tower': {'first': True, 'kills': 3}},
#   'teamId': 100,
#   'win': True},
#  {'bans': [],
#   'objectives': {'baron': {'first': False, 'kills': 0},
#    'champion': {'first': False, 'kills': 26},
#    'dragon': {'first': False, 'kills': 0},
#    'horde': {'first': False, 'kills': 0},
#    'inhibitor': {'first': False, 'kills': 0},
#    'riftHerald': {'first': False, 'kills': 0},
#    'tower': {'first': False, 'kills': 1}},
#   'teamId': 200,
#   'win': False}]

# %%
res6['info']['participants'][0].keys()
# Out:
# dict_keys(['allInPings', 'assistMePings', 'assists', 'baitPings', 'baronKills', 'basicPings', 'bountyLevel', 'challenges', 'champExperience', 'champLevel', 'championId', 'championName', 'championTransform', 'commandPings', 'consumablesPurchased', 'damageDealtToBuildings', 'damageDealtToObjectives', 'damageDealtToTurrets', 'damageSelfMitigated', 'dangerPings', 'deaths', 'detectorWardsPlaced', 'doubleKills', 'dragonKills', 'eligibleForProgression', 'enemyMissingPings', 'enemyVisionPings', 'firstBloodAssist', 'firstBloodKill', 'firstTowerAssist', 'firstTowerKill', 'gameEndedInEarlySurrender', 'gameEndedInSurrender', 'getBackPings', 'goldEarned', 'goldSpent', 'holdPings', 'individualPosition', 'inhibitorKills', 'inhibitorTakedowns', 'inhibitorsLost', 'item0', 'item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'itemsPurchased', 'killingSprees', 'kills', 'lane', 'largestCriticalStrike', 'largestKillingSpree', 'largestMultiKill', 'longestTimeSpentLiving', 'magicDamageDealt', 'magicDamage
# ...

# %%
url7 ='https://asia.api.riotgames.com/lol/match/v5/matches/KR_6855659717/timeline?api_key=RGAPI-f94a4128-cb3b-4303-b92b-0016fa59b5a8'

# %%
res7 = requests.get(url7).json()

# %%
res7
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6855659717',
#   'participants': ['xGIwwSPcoxVePrE2rm8lvKz0JWb1jaG5Ucz1U_KBaqcSywP4_Vk623omax8l8OE9J5_vPsQNqB7T_w',
#    'HZeupHnwhW3uHvd_q5xAeyBEzuH2xJ1uOzcmQ7UL6klsr_9RHRSOZcTuEsjNWD7hiuWMlLsM6SoCOw',
#    '8SqJYXnEYXUFwYd_tjJh-3VCARDzzzsONmbdzy_S3lUmS2Ue2fM215NGopadvIQQHyxpUlk9JX94Ww',
#    'ILvForIkTc9AHZ7g2dAwzOp5MqiSP0o11m_I-4xRgvM640rprYRJuzSlWR3tMa99MqBf8UvO4pIlPA',
#    '8N47foCQ8GdMj-5JxUnV2RO9EqSOKnk9ybhcjAMJ0i8cChXjlDdgGOFJST_O5a3lIJvlJ0jznfir1A',
#    'Ll7GsyGE3IW2P4PJpq24LBFzsDtnevfwlfkd-IHrsXOjW1avWYTHieFEZTDQXDmMB4qwSQ0UJELIKQ',
#    'wxS2WRA7dsUbeHei1vu5nNSVJDirzqrcxSjjiijkX9ML8c7OZtaZ5lS1PQRi0axbbYUULNMBf0dAOw',
#    'GvGy7uhoEcu0fWG60x-7gVrOF3wmsj2wndDQgUM4xuyi1WxbV6j5gfdKbUrI6dWeSkcwUGJwnUUE2Q',
#    '7-fXy8RDHRTcAhUPHDQTaLBljw3ZcaXZU2-l7_7n1a-W0TSdjoyX7TEFv8tlelY7BKPtpFp1dUd-ww',
#    '8jQErmNdePuEZPbr0eSZ3wuZ4rrs0442CyIkl6OtJzAAuT7_mdv-5WcFG8NWwgv-UOanv8ntBvhsdg']},
#  'info': {'frameInterval': 60000,
# ...

# %%
res7['metadata']
# Out:
# {'dataVersion': '2',
#  'matchId': 'KR_6855659717',
#  'participants': ['xGIwwSPcoxVePrE2rm8lvKz0JWb1jaG5Ucz1U_KBaqcSywP4_Vk623omax8l8OE9J5_vPsQNqB7T_w',
#   'HZeupHnwhW3uHvd_q5xAeyBEzuH2xJ1uOzcmQ7UL6klsr_9RHRSOZcTuEsjNWD7hiuWMlLsM6SoCOw',
#   '8SqJYXnEYXUFwYd_tjJh-3VCARDzzzsONmbdzy_S3lUmS2Ue2fM215NGopadvIQQHyxpUlk9JX94Ww',
#   'ILvForIkTc9AHZ7g2dAwzOp5MqiSP0o11m_I-4xRgvM640rprYRJuzSlWR3tMa99MqBf8UvO4pIlPA',
#   '8N47foCQ8GdMj-5JxUnV2RO9EqSOKnk9ybhcjAMJ0i8cChXjlDdgGOFJST_O5a3lIJvlJ0jznfir1A',
#   'Ll7GsyGE3IW2P4PJpq24LBFzsDtnevfwlfkd-IHrsXOjW1avWYTHieFEZTDQXDmMB4qwSQ0UJELIKQ',
#   'wxS2WRA7dsUbeHei1vu5nNSVJDirzqrcxSjjiijkX9ML8c7OZtaZ5lS1PQRi0axbbYUULNMBf0dAOw',
#   'GvGy7uhoEcu0fWG60x-7gVrOF3wmsj2wndDQgUM4xuyi1WxbV6j5gfdKbUrI6dWeSkcwUGJwnUUE2Q',
#   '7-fXy8RDHRTcAhUPHDQTaLBljw3ZcaXZU2-l7_7n1a-W0TSdjoyX7TEFv8tlelY7BKPtpFp1dUd-ww',
#   '8jQErmNdePuEZPbr0eSZ3wuZ4rrs0442CyIkl6OtJzAAuT7_mdv-5WcFG8NWwgv-UOanv8ntBvhsdg']}

# %%
res7['info']['participants']
# Out:
# [{'participantId': 1,
#   'puuid': 'xGIwwSPcoxVePrE2rm8lvKz0JWb1jaG5Ucz1U_KBaqcSywP4_Vk623omax8l8OE9J5_vPsQNqB7T_w'},
#  {'participantId': 2,
#   'puuid': 'HZeupHnwhW3uHvd_q5xAeyBEzuH2xJ1uOzcmQ7UL6klsr_9RHRSOZcTuEsjNWD7hiuWMlLsM6SoCOw'},
#  {'participantId': 3,
#   'puuid': '8SqJYXnEYXUFwYd_tjJh-3VCARDzzzsONmbdzy_S3lUmS2Ue2fM215NGopadvIQQHyxpUlk9JX94Ww'},
#  {'participantId': 4,
#   'puuid': 'ILvForIkTc9AHZ7g2dAwzOp5MqiSP0o11m_I-4xRgvM640rprYRJuzSlWR3tMa99MqBf8UvO4pIlPA'},
#  {'participantId': 5,
#   'puuid': '8N47foCQ8GdMj-5JxUnV2RO9EqSOKnk9ybhcjAMJ0i8cChXjlDdgGOFJST_O5a3lIJvlJ0jznfir1A'},
#  {'participantId': 6,
#   'puuid': 'Ll7GsyGE3IW2P4PJpq24LBFzsDtnevfwlfkd-IHrsXOjW1avWYTHieFEZTDQXDmMB4qwSQ0UJELIKQ'},
#  {'participantId': 7,
#   'puuid': 'wxS2WRA7dsUbeHei1vu5nNSVJDirzqrcxSjjiijkX9ML8c7OZtaZ5lS1PQRi0axbbYUULNMBf0dAOw'},
#  {'participantId': 8,
#   'puuid': 'GvGy7uhoEcu0fWG60x-7gVrOF3wmsj2wndDQgUM4xuyi1WxbV6j5gfdKbUrI6dWeSkcwUGJwnUUE2Q'},
#  {'participantId': 9,
# ...

# %%
res7['info']['frames'][0]['participantFrames']
# Out:
# {'1': {'championStats': {'abilityHaste': 0,
#    'abilityPower': 0,
#    'armor': 18,
#    'armorPen': 0,
#    'armorPenPercent': 0,
#    'attackDamage': 25,
#    'attackSpeed': 100,
#    'bonusArmorPenPercent': 0,
#    'bonusMagicPenPercent': 0,
#    'ccReduction': 0,
#    'cooldownReduction': 0,
#    'health': 580,
#    'healthMax': 580,
#    'healthRegen': 0,
#    'lifesteal': 0,
#    'magicPen': 0,
#    'magicPenPercent': 0,
#    'magicResist': 30,
#    'movementSpeed': 335,
#    'omnivamp': 0,
#    'physicalVamp': 0,
#    'power': 375,
#    'powerMax': 375,
#    'powerRegen': 0,
#    'spellVamp': 0},
#   'currentGold': 1400,
#   'damageStats': {'magicDamageDone': 0,
#    'magicDamageDoneToChampions': 0,
#    'magicDamageTaken': 0,
#    'physicalDamageDone': 0,
#    'physicalDamageDoneToChampions': 0,
#    'physicalDamageTaken': 0,
#    'totalDamageDone': 0,
#    'totalDamageDoneToChampions': 0,
#    'totalDamageTaken': 0,
#    'trueDamageDone': 0,
# ...

# %%
res7['info']['frames'][10].keys()
# Out:
# dict_keys(['events', 'participantFrames', 'timestamp'])

# %% [markdown]
# ## 1. suumoner_id or puu_id를 찾는다. (league-v4 or summoner v4)
# ## 2. puu_id 를 통해 match_id 를 찾는다(match v5)
# ## 3. match_id를 통해 matches, timeline 데이터를 찾아온다. (match v5)

# %%
url = f'https://kr.api.riotgames.com/lol/league/v4/challengerleagues/by-queue/RANKED_SOLO_5x5?api_key={riot_api_key}'

# %%
res = requests.get(url).json()

# %%
res
# Out:
# {'tier': 'CHALLENGER',
#  'leagueId': '966df365-7dea-34ca-839a-2cec050ba64a',
#  'queue': 'RANKED_SOLO_5x5',
#  'name': "Nami's Alliance",
#  'entries': [{'summonerId': 'NwR9Ri4PTjj-rVUNxuiBH83pVmodfceP2p380CsYkm7j8oM',
#    'summonerName': '불가사의 카르테',
#    'leaguePoints': 958,
#    'rank': 'I',
#    'wins': 266,
#    'losses': 226,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': True},
#   {'summonerId': 'wqj8cUSWGyTFpjUZ_42E1j-pvdHe91bOntdVYtB0AoDZSy0',
#    'summonerName': '나도안함걍',
#    'leaguePoints': 954,
#    'rank': 'I',
#    'wins': 259,
#    'losses': 198,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': True,
#    'hotStreak': True},
#   {'summonerId': 'H92q6TZ1cDBggLpEAeCEfNcl5Nr87HhZaAj4bGIhZBY88uw',
#    'summonerName': 'Karina167',
#    'leaguePoints': 1162,
#    'rank': 'I',
#    'wins': 197,
#    'losses': 142,
#    'veteran': False,
#    'inactive': False,
#    'freshBlood': False,
#    'hotStreak': False},
# ...

# %%
lst = [res['entries'][i]['summonerId'] for i in range(len(res['entries']))]

# %%
lst
# Out:
# ['NwR9Ri4PTjj-rVUNxuiBH83pVmodfceP2p380CsYkm7j8oM',
#  'wqj8cUSWGyTFpjUZ_42E1j-pvdHe91bOntdVYtB0AoDZSy0',
#  'H92q6TZ1cDBggLpEAeCEfNcl5Nr87HhZaAj4bGIhZBY88uw',
#  'Pqj6w8NMRID_HcSZNfrLt6_P_nnEVyaw94mbqjUAsWdik1nyX-e7ir9GZQ',
#  'Cc05B_pemQhsoUV5YLiSWuwy8K9jQWBOJWZ83RGQGYPThLo',
#  'xiYlVGOm8EDxzO7Lnl5yP3M0AQumAOfzB2xCSYnoop1HU-U',
#  'vxh3LvSykb6y_IoYkZmMULmr4FyYbdUSkcbIoKhNuVu9C5w',
#  'olpOKMDBPBY2AWew2dLRSJPLq7NMmfrbgspLWD46iS916wADtCnOI3Ry_g',
#  'igTxUTwtaR_99f9Yu2BiM3HeN0mcwICMLtqgYCxDViuE9ZQFoKC474aylA',
#  'aLGAeuNeTVarEHi7nM7ckVF2KWXcZBBhfTlMlQfo-y2Se33r1uFyO02D_Q',
#  'Q4K47NuB9ND1Ie1sdkd11mbDMX-tosNIqED8bNyLvyaN7wA',
#  'y9VOvRtFmghHvCGX0iry9WDKcUmD6upyxOtrWoqARNrcdjM',
#  'Yb2GPEp1XfkwO2lPeBVKFTZs15p1DC2fdG4YgXGZ8SFrR64',
#  '8iHdWGeDPyXrT318anoTkD0PInmTEAJEPyhyTHUeR21at9k',
#  'X6lIBOEui8qIpe76l6v1Glx_hCj69KfIbEFsPzAbgRVyW04',
#  '4GnH5w2mwPTqBbKNgOxK-7BVxOkSD-AxSHIoJ7LSljTExBCNJjRt2ybbkg',
#  'ri7vbqXQnXN0VNVsbBwzHliHFB92id4I64exghVHO-OZEok-',
# ...

# %%
summoner_id = lst[0]

# %%
riot_api_key = 'RGAPI-f94a4128-cb3b-4303-b92b-0016fa59b5a8'

# %%
url2 = f'https://kr.api.riotgames.com/lol/summoner/v4/summoners/{summoner_id}?api_key={riot_api_key}'

# %%
url2
# Out:
# 'https://kr.api.riotgames.com/lol/summoner/v4/summoners/NwR9Ri4PTjj-rVUNxuiBH83pVmodfceP2p380CsYkm7j8oM?api_key=RGAPI-f94a4128-cb3b-4303-b92b-0016fa59b5a8'

# %%
res2 = requests.get(url2).json()

# %%
res2
# Out:
# {'id': 'NwR9Ri4PTjj-rVUNxuiBH83pVmodfceP2p380CsYkm7j8oM',
#  'accountId': 'wsmIK8Mix6IkPzCgYu845JGVXDe5EMvdKFNmpTmSw-5z-DU',
#  'puuid': 'pzZVpA6GhXYfip9TMcdCR6EvU_q6c843FpHB-v5iqzITbVmVZOFYWrhC4CgJcnIJvoqdAplGmR9KIg',
#  'name': '불가사의 카르테',
#  'profileIconId': 5959,
#  'revisionDate': 1702583413000,
#  'summonerLevel': 743}

# %%
puuid = res2['puuid']

# %%
puuid
# Out:
# 'pzZVpA6GhXYfip9TMcdCR6EvU_q6c843FpHB-v5iqzITbVmVZOFYWrhC4CgJcnIJvoqdAplGmR9KIg'

# %%
url3 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start=0&count=20&api_key={riot_api_key}'

# %%
res3 = requests.get(url3).json()

# %%
res3
# Out:
# ['KR_6849612403',
#  'KR_6849596844',
#  'KR_6849572966',
#  'KR_6849542645',
#  'KR_6849529795',
#  'KR_6849452486',
#  'KR_6847175467',
#  'KR_6846168946',
#  'KR_6846149681',
#  'KR_6846108313',
#  'KR_6845839344',
#  'KR_6845586639',
#  'KR_6845521011',
#  'KR_6845437351',
#  'KR_6845401097',
#  'KR_6844724155',
#  'KR_6844710776',
#  'KR_6844708319',
#  'KR_6844691734',
#  'KR_6844684686']

# %%
match_id = res3[0]

# %%
match_id
# Out:
# 'KR_6849612403'

# %%
url4 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{match_id}?api_key={riot_api_key}'

# %%
res4 = requests.get(url4).json()

# %%
res4
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'KR_6849612403',
#   'participants': ['puE9ViwC4Xgdt0aHy4CTMMsbpZenBxNNMrjKM8giGvNnVElePprnRdQuftOOhCDPm19KVvITkFjHtQ',
#    'ILbcLGniIrLa36TNrwEYnGrn0rQQOm1gnlRB5oKzhWcq0P4HarX5RkCFGa1EmxDFyDD0ADqDDmwwKg',
#    'pzZVpA6GhXYfip9TMcdCR6EvU_q6c843FpHB-v5iqzITbVmVZOFYWrhC4CgJcnIJvoqdAplGmR9KIg',
#    '66yuQszKIS84eSqrS3Yl5wteUGJbHxZrTxaa5_awDTscKEHFCzr0odPO3k3q6apXOrUSjZMYZJ1Euw',
#    '_GvvUgbx1xAHYvnr2Xjca3TH4EMt9noMlE9xseNPShMBwfrKfjlwH03Qy0gXQ0E052leCztj9Mst4Q',
#    '8ieCFPBXZ8jSWkszLX2l67PByZAUNhourKLTZlsGssUDVeI21lHoUdkxlZyLQsPiWczegV_z58dMmA',
#    '_wTiC_j44q5kFW0vXngkKUmKatboTXGnKiXkBK6ifk6fINv7_PO9awu-9gSLoFHZoPqnOFC15j0VIA',
#    'IgGa396p-hWbyf-UFaWV-STNyKpMufd5eyF6UR4B4PodLBKoOR-D4vEHDWVu25GMkFVKwKSPc-XBKg',
#    'cQhtRarbhfw_uFgo-aUZKfS4PHrS_xh1c35UH7cdEYGPOJuADnggXfEUK--RuHucFHvIXvAC4tav_w',
#    '0d6ghQ1aENNkJPeRWmLxoycPuNHxNAz0UPJw-FQQidDuuBkWanaOfNnLaTXRcTtDf-x8vVjoILkb5w']},
#  'info': {'gameCreation': 1702581361630,
# ...

# %% [markdown]
# # 함수만들기

# %%
nickname = '깡통차기국내1위'
tag = 'KR1'

# %%
def account(nickname,tag):
    url0 =f'https://asia.api.riotgames.com/riot/account/v1/accounts/by-riot-id/{nickname}/{tag}?api_key={riot_api_key}'
    res0 = requests.get(url0).json()
    puuid = res2['puuid']
    return puuid

# %%
def get_puuid(puuid):
    url9 = f'https://asia.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?count=1&api_key={riot_api_key}'
    res9 = requests.get(url9).json()
    match_id = res9
    return match_id

# %%
def get_matches_timelines(matchid):
    url7 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}?api_key={riot_api_key}'
    matches = requests.get(url7).json()
    url6 = f'https://asia.api.riotgames.com/lol/match/v5/matches/{matchid}/timeline?api_key={riot_api_key}'
    timelines = requests.get(url6).json()
    return matches,timelines

# %%
account('깡통차기국내1위','kr1')
# Out:
# 'pzZVpA6GhXYfip9TMcdCR6EvU_q6c843FpHB-v5iqzITbVmVZOFYWrhC4CgJcnIJvoqdAplGmR9KIg'

# %%
get_puuid('pzZVpA6GhXYfip9TMcdCR6EvU_q6c843FpHB-v5iqzITbVmVZOFYWrhC4CgJcnIJvoqdAplGmR9KIg')
# Out:
# ['KR_6849612403']

# %%
get_matches_timelines('KR_6849612403')
# Out:
# ({'metadata': {'dataVersion': '2',
#    'matchId': 'KR_6849612403',
#    'participants': ['puE9ViwC4Xgdt0aHy4CTMMsbpZenBxNNMrjKM8giGvNnVElePprnRdQuftOOhCDPm19KVvITkFjHtQ',
#     'ILbcLGniIrLa36TNrwEYnGrn0rQQOm1gnlRB5oKzhWcq0P4HarX5RkCFGa1EmxDFyDD0ADqDDmwwKg',
#     'pzZVpA6GhXYfip9TMcdCR6EvU_q6c843FpHB-v5iqzITbVmVZOFYWrhC4CgJcnIJvoqdAplGmR9KIg',
#     '66yuQszKIS84eSqrS3Yl5wteUGJbHxZrTxaa5_awDTscKEHFCzr0odPO3k3q6apXOrUSjZMYZJ1Euw',
#     '_GvvUgbx1xAHYvnr2Xjca3TH4EMt9noMlE9xseNPShMBwfrKfjlwH03Qy0gXQ0E052leCztj9Mst4Q',
#     '8ieCFPBXZ8jSWkszLX2l67PByZAUNhourKLTZlsGssUDVeI21lHoUdkxlZyLQsPiWczegV_z58dMmA',
#     '_wTiC_j44q5kFW0vXngkKUmKatboTXGnKiXkBK6ifk6fINv7_PO9awu-9gSLoFHZoPqnOFC15j0VIA',
#     'IgGa396p-hWbyf-UFaWV-STNyKpMufd5eyF6UR4B4PodLBKoOR-D4vEHDWVu25GMkFVKwKSPc-XBKg',
#     'cQhtRarbhfw_uFgo-aUZKfS4PHrS_xh1c35UH7cdEYGPOJuADnggXfEUK--RuHucFHvIXvAC4tav_w',
#     '0d6ghQ1aENNkJPeRWmLxoycPuNHxNAz0UPJw-FQQidDuuBkWanaOfNnLaTXRcTtDf-x8vVjoILkb5w']},
# ...
