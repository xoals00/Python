# %%
import pandas as pd
from my_utils import *
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
font_path = "C:/Windows/Fonts/gulim.ttc"
font = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font) # 윈도우

# %%
conn = connect_mysql()
query = 'select * from lol_datas_iron'
df_iron = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()

# %%
df_iron = df_iron[df_iron.teamPosition != ""]

df_iron = df_iron.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_iron['Sum_Selected'] = df_iron[selected_columns].sum(axis=1)

# 결과 출력
df_iron
# Out:
#              gameId  gameDuration  allInPings  assistMePings  basicPings  \
# 0     KR_6841974869          1861           0              0           0
# 1     KR_6841974869          1861           0              1           0
# 2     KR_6841974869          1861           1              2           0
# 3     KR_6841974869          1861           0              2           0
# 4     KR_6841974869          1861           0              2           0
# ...             ...           ...         ...            ...         ...
# 7783  KR_6866314283          1744           0              1           0
# 7784  KR_6866314283          1744           0              0           0
# 7785  KR_6866314283          1744           0             11           0
# 7786  KR_6866314283          1744           0              0           0
# 7787  KR_6866314283          1744           1              3           0
#
#       commandPings  dangerPings  enemyMissingPings  getBackPings  \
# ...

# %%
df_bronzeconn = connect_mysql()
query = 'select * from lol_datas_bronze'
df_bronze = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 df_bronzeconn = connect_mysql()
#       2 query = 'select * from lol_datas_bronze'
# ----> 3 df_bronze = pd.DataFrame(sql_execute_dict(conn,query))
#       4 conn.close()
#
# File ~\Untitled Folder\my_utils.py:34, in sql_execute_dict(conn, query)
#      32 def sql_execute_dict(conn, query):
#      33     cursor = conn.cursor(cursor=pymysql.cursors.DictCursor)
# ---> 34     cursor.execute(query)
#      35     result = cursor.fetchall()
#      36     return result
#
# File ~\anaconda3\Lib\site-packages\pymysql\cursors.py:148, in Cursor.execute(self, query, args)
#     144     pass
#     146 query = self.mogrify(query, args)
# --> 148 result = self._query(query)
#     149 self._executed = query
#     150 return result
#
# ...

# %%
df_bronze = df_bronze[df_bronze.teamPosition != ""]

df_bronze = df_bronze.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_bronze['Sum_Selected'] = df_bronze[selected_columns].sum(axis=1)

# 결과 출력
df_bronze

# %%
conn = connect_mysql()
query = 'select * from lol_datas_silver'
df_silver = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()

# %%
df_silver = df_silver[df_silver.teamPosition != ""]

df_silver = df_silver.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_silver['Sum_Selected'] = df_silver[selected_columns].sum(axis=1)

# 결과 출력
df_silver

# %%
conn = connect_mysql()
query = 'select * from lol_datas_gold'
df_gold = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()

# %%
df_gold = df_gold[df_gold.teamPosition != ""]

df_gold = df_gold.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_gold['Sum_Selected'] = df_gold[selected_columns].sum(axis=1)

# 결과 출력
df_gold

# %%
conn = connect_mysql()
query = 'select * from lol_datas_platinum'
df_platinum = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()

# %%
df_platinum = df_platinum[df_platinum.teamPosition != ""]

df_platinum = df_platinum.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_platinum['Sum_Selected'] = df_platinum[selected_columns].sum(axis=1)

# 결과 출력
df_platinum

# %%
conn = connect_mysql()
query = 'select * from lol_datas_emerald'
df_emerald = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()

# %%
df_emerald = df_emerald[df_emerald.teamPosition != ""]

df_emerald = df_emerald.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_emerald['Sum_Selected'] = df_emerald[selected_columns].sum(axis=1)

# 결과 출력
df_emerald

# %%
conn = connect_mysql()
query = 'select * from lol_datas_diamond'
df_diamond = pd.DataFrame(sql_execute_dict(conn,query))
conn.close()

# %%
df_diamond = df_diamond[df_diamond.teamPosition != ""]

df_diamond = df_diamond.drop(columns=['visionClearedPings','holdPings','baitPings'],axis=1)

selected_columns = ['allInPings', 'assistMePings','commandPings','basicPings','dangerPings','getBackPings','onMyWayPings','needVisionPings','enemyMissingPings','pushPings']
df_diamond['Sum_Selected'] = df_diamond[selected_columns].sum(axis=1)

# 결과 출력
df_diamond

# %%
import pandas as pd

# 예시 데이터프레임 생성
data = {'win': [True, False, True],
        'numbers': [10, 20, 30]}
df = pd.DataFrame(data)

# 'win'이 True인 행의 'numbers' 값 합계
sum_true = df_iron.loc[df_iron['win'] == 'True', 'Sum_Selected'].sum()

# 'win'이 False인 행의 'numbers' 값 합계
sum_false = df_iron.loc[df_iron['win'] == 'False', 'Sum_Selected'].sum()

# 결과 출력
print("Sum for True: ", sum_true)
print("Sum for False: ", sum_false)

# 합계를 비교
if sum_true > sum_false:
    print("True has a higher sum.")
elif sum_true < sum_false:
    print("False has a higher sum.")
else:
    print("Sums are equal.")

# %%
selected_rows = df_iron[(df_iron['g_2'] >= 900) & (df_iron['win'] == 'True')]

# 전체 판수
total_games = len(df_iron[df_iron['g_2'] >= 900])

print(total_games)

# 조건에 해당하는 판수
selected_games = len(selected_rows)

print(selected_games)

# 승률 계산
win_rate = selected_games / total_games * 100

# %%
iron_issue_win = round(win_rate, 1)
# bro_issue_win = round(win_rate, 1)
# sil_issue_win = round(win_rate, 1)
# gold_no_issue_win = round(win_rate, 1)
# pla_issue_win = round(win_rate, 1)
# eme_issue_win = round(win_rate, 1)
#dia_issue_win = round(win_rate, 1)

# %%
bro_issue_win

# %%
tiers = ['IRON', 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'EMERALD', 'DIAMOND']

result_df = pd.DataFrame(index=tiers, columns=['이긴 팀의 총 핑 횟수', '진 팀의 총 핑 횟수'])

# %%
result_df.loc['IRON', '이긴 팀의 총 핑 횟수'] = sum_true
result_df.loc['IRON', '진 팀의 총 핑 횟수'] = sum_false

# %%
result_df

# %%
result_final = pd.merge(result_final,df_iron, how = 'outer')

# %%
result_final

# %%
df_iron

# %%
result_final.to_csv('result_final.csv', index=False)

# %%
df = pd.read_csv('result_df_issue.csv')
df

# %%
df = pd.read_csv('result_df(ping).csv')
df
# Out:
#    이긴 팀의 총 핑 횟수  진 팀의 총 핑 횟수
# 0         76723        71748
# 1         86587        79414
# 2         92112        82894
# 3         95747        85716
# 4         95002        82432
# 5        112815        97429
# 6        116391       101777

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
from matplotlib import pyplot as plt

# %%
x = tiers
y = df['이긴 팀의 총 핑 횟수']
y2 = df['진 팀의 총 핑 횟수']

plt.title('티어별 핑')
plt.plot(x,y ,label = '이긴 팀')
plt.plot(x,y2, label = '진 팀')
plt.legend()
plt.show()

# %%
plt.figure()
plt.title('정글 시간당 골드')
sns.kdeplot(x=lol_tmp['15분 골드'], label = '15분 골드')
sns.kdeplot(x=lol_tmp['20분 골드'], label = '20분 골드')
plt.legend(loc=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 plt.figure()
#       2 plt.title('정글 시간당 골드')
# ----> 3 sns.kdeplot(x=lol_tmp['15분 골드'], label = '15분 골드')
#       4 sns.kdeplot(x=lol_tmp['20분 골드'], label = '20분 골드')
#       5 plt.legend(loc=4)
#
# NameError: name 'sns' is not defined
